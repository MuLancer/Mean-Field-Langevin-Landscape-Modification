# %% [markdown]
# # MNIST Experiment

# %% [markdown]
# - Group A (PGD vs. PGD-LM)
# - Group B (NPGD vs. NPGD-LM)
# - Group C (SGD with 5 independent runs vs. Particle Based SGD-LM)
# - Group D (Adagrad with 5 independent runs vs. Particle Based Adagrad-LM)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import copy
import numpy as np
import matplotlib.pyplot as plt


torch.manual_seed(0)
np.random.seed(0)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Define transforms and load MNIST (train/test split)

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])
train_dataset = torchvision.datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset  = torchvision.datasets.MNIST(root='./data', train=False, transform=transform, download=True)
train_loader  = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=64, shuffle=True)
test_loader   = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=1000, shuffle=False)

# %% [markdown]
# ## Model

# %%
num_particles = 5
num_epochs = 50

# %%
class SimpleMLP(nn.Module):
    def __init__(self, input_dim=28*28, hidden_dim=128, output_dim=10):
        super(SimpleMLP, self).__init__()
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, output_dim)
    def forward(self, x):
        x = x.view(x.size(0), -1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

criterion = nn.CrossEntropyLoss()

# Common initial states for all optimizers
def get_initial_states(num_states):
    base_model = SimpleMLP()
    initial_states = []
    for _ in range(num_states):
        initial_states.append(copy.deepcopy(base_model.state_dict()))
        base_model.apply(lambda m: m.reset_parameters() if hasattr(m, "reset_parameters") else None)
    return initial_states

initial_states = get_initial_states(num_particles)

def load_models_from_states(states):
    models = []
    for state in states:
        model = SimpleMLP().to(device)
        model.load_state_dict(state)
        models.append(model)
    return models

def evaluate_loss(models, loader):
    total_loss = 0.0
    total_count = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs_sum = 0
            for m in models:
                outputs_sum += m(images)
            outputs_avg = outputs_sum / len(models)
            loss = criterion(outputs_avg, labels).item()
            total_loss += loss * images.size(0)
            total_count += images.size(0)
    return total_loss / total_count

# %% [markdown]
# ### Group A Update Functions

# %%
def update_PGD(model, optimizer, images, labels, noise_std=1e-3):
    # Standard update with additive noise (non-)
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    with torch.no_grad():
        for p in model.parameters():
            p.add_(torch.randn_like(p) * noise_std)
    return loss.item()

def update_PGD_LM(model, optimizer, images, labels, iter, c, alpha_init=0.1, decay_factor=0.99, epsilon=1, f_func=lambda x: x):
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward(retain_graph=True)
    total_norm = 0.0
    for p in model.parameters():
        if p.grad is not None:
            total_norm += p.grad.data.norm(2).item() ** 2
    G_t = loss.item()
    alpha_t = alpha_init * (decay_factor ** iter)
    mod_factor = alpha_t * f_func(max(0, G_t - c)) + epsilon
    with torch.no_grad():
        for p in model.parameters():
            if p.grad is not None:
                p.grad.data.div_(mod_factor)
    optimizer.step()
    return loss.item()

# %% [markdown]
# ### Group B Update Functions

# %%
def update_NPGD(model, optimizer, images, labels, stepsize, tau=0.001):
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward()
    # Instead of calling optimizer.step(), we manually update parameters:
    with torch.no_grad():
        for p in model.parameters():
            #  update: p = p - stepsize * grad + sqrt(2*stepsize*tau) * randn
            noise = torch.randn_like(p) * (2 * stepsize * tau)**0.5
            p.data = p.data - stepsize * p.grad.data + noise
    return loss.item()

def update_NPGD_LM(model, optimizer, images, labels, stepsize, iter, c, tau=0.001, alpha_init=0.1, decay_factor=0.99, epsilon=1, f_func=lambda x: x):
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward(retain_graph=True)
    total_norm = 0.0
    for p in model.parameters():
        if p.grad is not None:
            total_norm += p.grad.data.norm(2).item() ** 2
    G_t = loss.item()
    alpha_t = alpha_init * (decay_factor ** iter)
    mod_factor = alpha_t * f_func(max(0, G_t - c)) + epsilon
    # Apply LM scaling to gradient and perform  update
    with torch.no_grad():
        for p in model.parameters():
            if p.grad is not None:
                scaled_grad = p.grad.data / mod_factor
                noise = torch.randn_like(p) * (2 * stepsize * tau)**0.5
                p.data = p.data - stepsize * scaled_grad + noise
    optimizer.zero_grad() 
    return loss.item()

# %% [markdown]
# ### Group C Update Functions

# %%
def update_SGD(model, optimizer, images, labels):
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    return loss.item()

def update_SGD_LM(model, optimizer, images, labels, iter, c, alpha_init=0.1, decay_factor=0.99, epsilon=1, f_func=lambda x: x):
    optimizer.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward(retain_graph=True)
    total_norm = 0.0
    for p in model.parameters():
        if p.grad is not None:
            total_norm += p.grad.data.norm(2).item() ** 2
    G_t = loss.item()
    alpha_t = alpha_init * (decay_factor ** iter)
    mod_factor = alpha_t * f_func(max(0, G_t - c)) + epsilon
    with torch.no_grad():
        for p in model.parameters():
            if p.grad is not None:
                p.grad.data.div_(mod_factor)
    optimizer.step()
    return loss.item()

# %% [markdown]
# ### Group D Update Functions

# %%
def init_adagrad_state(model):
    state = {}
    for p in model.parameters():
        state[id(p)] = torch.zeros_like(p.data)
    return state

def update_adagrad_LM(model, state, images, labels, iter, c, alpha_init=0.1, decay_factor=0.99, epsilon=1, f_func=lambda x: x):
    model.zero_grad()
    outputs = model(images)
    loss = criterion(outputs, labels)
    loss.backward()
    total_norm_sq = 0.0
    adjusted_grads = {}
    with torch.no_grad():
        for p in model.parameters():
            if p.grad is not None:
                state[id(p)] += p.grad.data.pow(2)
                adjusted = p.grad.data / (state[id(p)].sqrt() + 1e-8)
                adjusted_grads[id(p)] = adjusted
                total_norm_sq += adjusted.pow(2).sum().item()
    G_t = total_norm_sq ** 0.5
    alpha_t = alpha_init * (decay_factor ** iter)
    mod_factor = alpha_t * f_func(max(0, G_t - c)) + epsilon
    with torch.no_grad():
        for p in model.parameters():
            if p.grad is not None:
                final_grad = adjusted_grads[id(p)] / mod_factor
                p.data.sub_(final_grad)
    model.zero_grad()
    return loss.item()

# %% [markdown]
# ## Run Experiment

# %%
def evaluate(models, loader):
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs_sum = 0
            for m in models:
                outputs_sum += m(images)
            outputs_avg = outputs_sum / len(models)
            _, predicted = torch.max(outputs_avg, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total


def run_experiment_A(num_epochs=5, noise_std=1e-3, alpha_init=0.1, decay_factor=0.99, epsilon=1):
    models_A_PGD    = load_models_from_states(initial_states)
    models_A_PGD_LM = load_models_from_states(initial_states)
    
    optim_A_PGD    = [optim.SGD(m.parameters(), lr=0.1) for m in models_A_PGD]
    optim_A_PGD_LM = [optim.SGD(m.parameters(), lr=0.1) for m in models_A_PGD_LM]
    
    global_iter = 0
    train_loss_history = {'PGD': [], 'PGD-LM': []}
    test_loss_history  = {'PGD': [], 'PGD-LM': []}
    
    for epoch in range(num_epochs):
        epoch_losses_PGD = []
        epoch_losses_PGD_LM = []
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            # PGD update (standard noisy update)
            loss_batch = 0.0
            for m, opt in zip(models_A_PGD, optim_A_PGD):
                loss_batch += update_PGD(m, opt, images, labels, noise_std)
            epoch_losses_PGD.append(loss_batch / num_particles)
            # PGD-LM update
            losses = []
            for m in models_A_PGD_LM:
                with torch.no_grad():
                    out = m(images)
                    losses.append(criterion(out, labels).item())
            avg_loss = np.mean(losses)
            loss_batch = 0.0
            for m, opt in zip(models_A_PGD_LM, optim_A_PGD_LM):
                loss_batch += update_PGD_LM(m, opt, images, labels, global_iter, avg_loss,
                                              alpha_init, decay_factor, epsilon)
            epoch_losses_PGD_LM.append(loss_batch / num_particles)
            global_iter += 1
        train_loss_PGD    = np.mean(epoch_losses_PGD)
        train_loss_PGD_LM = np.mean(epoch_losses_PGD_LM)
        train_loss_history['PGD'].append(train_loss_PGD)
        train_loss_history['PGD-LM'].append(train_loss_PGD_LM)
        
        test_loss_PGD    = evaluate_loss(models_A_PGD, test_loader)
        test_loss_PGD_LM = evaluate_loss(models_A_PGD_LM, test_loader)
        test_loss_history['PGD'].append(test_loss_PGD)
        test_loss_history['PGD-LM'].append(test_loss_PGD_LM)
        
        print(f"[Group A] Epoch {epoch+1}/{num_epochs}: PGD Train Loss = {train_loss_PGD:.4f}, Test Loss = {test_loss_PGD:.4f} | "
              f"PGD-LM Train Loss = {train_loss_PGD_LM:.4f}, Test Loss = {test_loss_PGD_LM:.4f}")
    return train_loss_history, test_loss_history, models_A_PGD, models_A_PGD_LM


def run_experiment_B(num_epochs=5, stepsize=0.08, tau=0.01, alpha_init=0.1, decay_factor=0.99, epsilon=1, f_func=lambda x:x):
    models_B_NPGD    = load_models_from_states(initial_states)
    models_B_NPGD_LM = load_models_from_states(initial_states)
    
    optim_B_NPGD    = [optim.SGD(m.parameters(), lr=stepsize) for m in models_B_NPGD]
    optim_B_NPGD_LM = [optim.SGD(m.parameters(), lr=stepsize) for m in models_B_NPGD_LM]
    
    global_iter = 0
    train_loss_history = {'NPGD': [], 'NPGD-LM': []}
    test_loss_history  = {'NPGD': [], 'NPGD-LM': []}
    
    for epoch in range(num_epochs):
        epoch_losses_NPGD = []
        epoch_losses_NPGD_LM = []
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            #  NPGD update
            loss_batch = 0.0
            for m, opt in zip(models_B_NPGD, optim_B_NPGD):
                loss_batch += update_NPGD(m, opt, images, labels, stepsize, tau)
            epoch_losses_NPGD.append(loss_batch / num_particles)
            
            #  NPGD-LM update
            losses = []
            for m in models_B_NPGD_LM:
                with torch.no_grad():
                    out = m(images)
                    losses.append(criterion(out, labels).item())
            avg_loss = np.mean(losses)
            loss_batch = 0.0
            for m, opt in zip(models_B_NPGD_LM, optim_B_NPGD_LM):
                loss_batch += update_NPGD_LM(m, opt, images, labels, stepsize, global_iter, avg_loss, tau, alpha_init, decay_factor, epsilon, f_func)
            epoch_losses_NPGD_LM.append(loss_batch / num_particles)
            global_iter += 1
        train_loss_NPGD    = np.mean(epoch_losses_NPGD)
        train_loss_NPGD_LM = np.mean(epoch_losses_NPGD_LM)
        train_loss_history['NPGD'].append(train_loss_NPGD)
        train_loss_history['NPGD-LM'].append(train_loss_NPGD_LM)
        
        test_loss_NPGD    = evaluate_loss(models_B_NPGD, test_loader)
        test_loss_NPGD_LM = evaluate_loss(models_B_NPGD_LM, test_loader)
        test_loss_history['NPGD'].append(test_loss_NPGD)
        test_loss_history['NPGD-LM'].append(test_loss_NPGD_LM)
        
        print(f"[Group B] Epoch {epoch+1}/{num_epochs}:  NPGD Train Loss = {train_loss_NPGD:.4f}, Test Loss = {test_loss_NPGD:.4f} | "
              f" NPGD-LM Train Loss = {train_loss_NPGD_LM:.4f}, Test Loss = {test_loss_NPGD_LM:.4f}")
    return train_loss_history, test_loss_history, models_B_NPGD, models_B_NPGD_LM

def run_experiment_C(num_epochs=5, alpha_init=0.1, decay_factor=0.99, epsilon=1):
    # "SGD with 5 runs" (independent runs)
    models_C_ind = load_models_from_states(initial_states)
    optim_C_ind = [optim.SGD(m.parameters(), lr=0.1) for m in models_C_ind]
    train_loss_history_ind = []
    test_loss_history_ind = []
    for epoch in range(num_epochs):
        epoch_losses = []
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            batch_loss = 0.0
            for m, opt in zip(models_C_ind, optim_C_ind):
                batch_loss += update_SGD(m, opt, images, labels)
            epoch_losses.append(batch_loss / num_particles)
        avg_epoch_loss = np.mean(epoch_losses)
        train_loss_history_ind.append(avg_epoch_loss)
        test_loss_history_ind.append(evaluate_loss(models_C_ind, test_loader))
        print(f"[Group C] Epoch {epoch+1}/{num_epochs} SGD with 5 runs: Train Loss = {avg_epoch_loss:.4f}, Test Loss = {test_loss_history_ind[-1]:.4f}")
    
    # Particle Based SGD-LM
    models_C_lm = load_models_from_states(initial_states)
    optim_C_lm = [optim.SGD(m.parameters(), lr=0.1) for m in models_C_lm]
    global_iter = 0
    train_loss_history_lm = []
    test_loss_history_lm = []
    for epoch in range(num_epochs):
        epoch_losses = []
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            losses = []
            for m in models_C_lm:
                with torch.no_grad():
                    out = m(images)
                    losses.append(criterion(out, labels).item())
            avg_loss = np.mean(losses)
            batch_loss = 0.0
            for m, opt in zip(models_C_lm, optim_C_lm):
                batch_loss += update_SGD_LM(m, opt, images, labels, global_iter, avg_loss,
                                          alpha_init, decay_factor, epsilon)
            epoch_losses.append(batch_loss / num_particles)
            global_iter += 1
        avg_epoch_loss = np.mean(epoch_losses)
        train_loss_history_lm.append(avg_epoch_loss)
        test_loss_history_lm.append(evaluate_loss(models_C_lm, test_loader))
        print(f"[Group C] Epoch {epoch+1}/{num_epochs} Particle Based SGD-LM: Train Loss = {avg_epoch_loss:.4f}, Test Loss = {test_loss_history_lm[-1]:.4f}")
    return train_loss_history_ind, test_loss_history_ind, train_loss_history_lm, test_loss_history_lm, models_C_ind, models_C_lm

def run_experiment_D(num_epochs=5, alpha_init=0.1, decay_factor=0.99, epsilon=1, f_func=lambda x: x):
    # "Adagrad with 5 runs" (independent runs)
    models_D_ind = load_models_from_states(initial_states)
    optim_D_ind = [optim.Adagrad(m.parameters(), lr=0.1) for m in models_D_ind]
    train_loss_history_ind = []
    test_loss_history_ind = []
    for epoch in range(num_epochs):
        epoch_losses = []
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            batch_loss = 0.0
            for m, opt in zip(models_D_ind, optim_D_ind):
                batch_loss += update_SGD(m, opt, images, labels)
            epoch_losses.append(batch_loss / num_particles)
        avg_epoch_loss = np.mean(epoch_losses)
        train_loss_history_ind.append(avg_epoch_loss)
        test_loss_history_ind.append(evaluate_loss(models_D_ind, test_loader))
        print(f"[Group D] Epoch {epoch+1}/{num_epochs} Adagrad with 5 runs: Train Loss = {avg_epoch_loss:.4f}, Test Loss = {test_loss_history_ind[-1]:.4f}")
    
    # Particle Based Adagrad-LM
    models_D_lm = load_models_from_states(initial_states)
    adagrad_states = [init_adagrad_state(m) for m in models_D_lm]
    global_iter = 0
    train_loss_history_lm = []
    test_loss_history_lm = []
    for epoch in range(num_epochs):
        epoch_losses = []
        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            losses = []
            for m in models_D_lm:
                with torch.no_grad():
                    out = m(images)
                    losses.append(criterion(out, labels).item())
            avg_loss = np.mean(losses)
            batch_loss = 0.0
            for m, state in zip(models_D_lm, adagrad_states):
                batch_loss += update_adagrad_LM(m, state, images, labels, global_iter, avg_loss,
                                                  alpha_init, decay_factor, epsilon, f_func=lambda x: x)
            epoch_losses.append(batch_loss / num_particles)
            global_iter += 1
        avg_epoch_loss = np.mean(epoch_losses)
        train_loss_history_lm.append(avg_epoch_loss)
        test_loss_history_lm.append(evaluate_loss(models_D_lm, test_loader))
        print(f"[Group D] Epoch {epoch+1}/{num_epochs} Particle Based Adagrad-LM: Train Loss = {avg_epoch_loss:.4f}, Test Loss = {test_loss_history_lm[-1]:.4f}")
    return train_loss_history_ind, test_loss_history_ind, train_loss_history_lm, test_loss_history_lm, models_D_ind, models_D_lm

# %%
(train_loss_A, test_loss_A, models_A_PGD, models_A_PGD_LM) = run_experiment_A(num_epochs=num_epochs)
(train_loss_B, test_loss_B, models_B_NPGD, models_B_NPGD_LM) = run_experiment_B(num_epochs=num_epochs, stepsize=0.08, tau=1e-5)
(loss_B_ind_train, loss_B_ind_test, loss_B_lm_train, loss_B_lm_test, models_C_ind, models_C_lm) = run_experiment_C(num_epochs=num_epochs)
(loss_C_ind_train, loss_C_ind_test, loss_C_lm_train, loss_C_lm_test, models_D_ind, models_D_lm) = run_experiment_D(num_epochs=num_epochs)
# Out:
# [Group A] Epoch 1/50: PGD Train Loss = 0.3962, Test Loss = 0.2060 | PGD-LM Train Loss = 0.3927, Test Loss = 0.2023
# [Group A] Epoch 2/50: PGD Train Loss = 0.1846, Test Loss = 0.2030 | PGD-LM Train Loss = 0.1785, Test Loss = 0.2205
# [Group A] Epoch 3/50: PGD Train Loss = 0.1396, Test Loss = 0.1192 | PGD-LM Train Loss = 0.1316, Test Loss = 0.1273
# [Group A] Epoch 4/50: PGD Train Loss = 0.1169, Test Loss = 0.1643 | PGD-LM Train Loss = 0.1076, Test Loss = 0.1710
# [Group A] Epoch 5/50: PGD Train Loss = 0.1017, Test Loss = 0.0882 | PGD-LM Train Loss = 0.0914, Test Loss = 0.0889
# [Group A] Epoch 6/50: PGD Train Loss = 0.0905, Test Loss = 0.0946 | PGD-LM Train Loss = 0.0789, Test Loss = 0.0960
# [Group A] Epoch 7/50: PGD Train Loss = 0.0822, Test Loss = 0.0789 | PGD-LM Train Loss = 0.0701, Test Loss = 0.0759
# [Group A] Epoch 8/50: PGD Train Loss = 0.0743, Test Loss = 0.0730 | PGD-LM Train Loss = 0.0618, Test Loss = 0.0688
# [Group A] Epoch 9/50: PGD Train Loss = 0.0690, Test Loss = 0.0847 | PGD-LM Train Loss = 0.0556, Test Loss = 0.0796
# [Group A] Epoch 10/50: PGD Train Loss = 0.0644, Test Loss = 0.0734 | PGD-LM Train Loss = 0.0503, Test Loss = 0.0723
# [Group A] Epoch 11/50: PGD Train Loss = 0.0611, Test Loss = 0.0687 | PGD-LM Train Loss = 0.0459, Test Loss = 0.0648
# [Group A] Epoch 12/50: PGD Train Loss = 0.0576, Test Loss = 0.0721 | PGD-LM Train Loss = 0.0415, Test Loss = 0.0700
# [Group A] Epoch 13/50: PGD Train Loss = 0.0535, Test Loss = 0.0679 | PGD-LM Train Loss = 0.0377, Test Loss = 0.0666
# [Group A] Epoch 14/50: PGD Train Loss = 0.0511, Test Loss = 0.0698 | PGD-LM Train Loss = 0.0347, Test Loss = 0.0696
# [Group A] Epoch 15/50: PGD Train Loss = 0.0481, Test Loss = 0.0642 | PGD-LM Train Loss = 0.0312, Test Loss = 0.0662
# [Group A] Epoch 16/50: PGD Train Loss = 0.0458, Test Loss = 0.0682 | PGD-LM Train Loss = 0.0284, Test Loss = 0.0619
# [Group A] Epoch 17/50: PGD Train Loss = 0.0431, Test Loss = 0.1240 | PGD-LM Train Loss = 0.0257, Test Loss = 0.1024
# [Group A] Epoch 18/50: PGD Train Loss = 0.0424, Test Loss = 0.0725 | PGD-LM Train Loss = 0.0245, Test Loss = 0.0739
# [Group A] Epoch 19/50: PGD Train Loss = 0.0402, Test Loss = 0.0671 | PGD-LM Train Loss = 0.0215, Test Loss = 0.0644
# [Group A] Epoch 20/50: PGD Train Loss = 0.0384, Test Loss = 0.0744 | PGD-LM Train Loss = 0.0196, Test Loss = 0.0637
# [Group A] Epoch 21/50: PGD Train Loss = 0.0368, Test Loss = 0.0659 | PGD-LM Train Loss = 0.0178, Test Loss = 0.0627
# [Group A] Epoch 22/50: PGD Train Loss = 0.0352, Test Loss = 0.0693 | PGD-LM Train Loss = 0.0161, Test Loss = 0.0653
# [Group A] Epoch 23/50: PGD Train Loss = 0.0334, Test Loss = 0.0664 | PGD-LM Train Loss = 0.0148, Test Loss = 0.0607
# [Group A] Epoch 24/50: PGD Train Loss = 0.0324, Test Loss = 0.0679 | PGD-LM Train Loss = 0.0131, Test Loss = 0.0617
# [Group A] Epoch 25/50: PGD Train Loss = 0.0313, Test Loss = 0.0712 | PGD-LM Train Loss = 0.0122, Test Loss = 0.0640
# [Group A] Epoch 26/50: PGD Train Loss = 0.0298, Test Loss = 0.0700 | PGD-LM Train Loss = 0.0110, Test Loss = 0.0647
# [Group A] Epoch 27/50: PGD Train Loss = 0.0290, Test Loss = 0.0704 | PGD-LM Train Loss = 0.0100, Test Loss = 0.0639
# [Group A] Epoch 28/50: PGD Train Loss = 0.0279, Test Loss = 0.0718 | PGD-LM Train Loss = 0.0087, Test Loss = 0.0650
# [Group A] Epoch 29/50: PGD Train Loss = 0.0272, Test Loss = 0.0728 | PGD-LM Train Loss = 0.0078, Test Loss = 0.0648
# [Group A] Epoch 30/50: PGD Train Loss = 0.0265, Test Loss = 0.0682 | PGD-LM Train Loss = 0.0070, Test Loss = 0.0639
# [Group A] Epoch 31/50: PGD Train Loss = 0.0255, Test Loss = 0.0717 | PGD-LM Train Loss = 0.0060, Test Loss = 0.0627
# [Group A] Epoch 32/50: PGD Train Loss = 0.0250, Test Loss = 0.0755 | PGD-LM Train Loss = 0.0057, Test Loss = 0.0658
# [Group A] Epoch 33/50: PGD Train Loss = 0.0251, Test Loss = 0.0811 | PGD-LM Train Loss = 0.0052, Test Loss = 0.0805
# [Group A] Epoch 34/50: PGD Train Loss = 0.0238, Test Loss = 0.0748 | PGD-LM Train Loss = 0.0045, Test Loss = 0.0653
# [Group A] Epoch 35/50: PGD Train Loss = 0.0239, Test Loss = 0.0734 | PGD-LM Train Loss = 0.0041, Test Loss = 0.0655
# [Group A] Epoch 36/50: PGD Train Loss = 0.0228, Test Loss = 0.0718 | PGD-LM Train Loss = 0.0038, Test Loss = 0.0669
# [Group A] Epoch 37/50: PGD Train Loss = 0.0229, Test Loss = 0.0754 | PGD-LM Train Loss = 0.0035, Test Loss = 0.0645
# [Group A] Epoch 38/50: PGD Train Loss = 0.0215, Test Loss = 0.0861 | PGD-LM Train Loss = 0.0029, Test Loss = 0.0691
# [Group A] Epoch 39/50: PGD Train Loss = 0.0213, Test Loss = 0.0792 | PGD-LM Train Loss = 0.0028, Test Loss = 0.0665
# [Group A] Epoch 40/50: PGD Train Loss = 0.0212, Test Loss = 0.0941 | PGD-LM Train Loss = 0.0026, Test Loss = 0.0720
# [Group A] Epoch 41/50: PGD Train Loss = 0.0204, Test Loss = 0.0792 | PGD-LM Train Loss = 0.0024, Test Loss = 0.0663
# [Group A] Epoch 42/50: PGD Train Loss = 0.0198, Test Loss = 0.0812 | PGD-LM Train Loss = 0.0023, Test Loss = 0.0678
# [Group A] Epoch 43/50: PGD Train Loss = 0.0188, Test Loss = 0.0804 | PGD-LM Train Loss = 0.0021, Test Loss = 0.0669
# [Group A] Epoch 44/50: PGD Train Loss = 0.0186, Test Loss = 0.0788 | PGD-LM Train Loss = 0.0020, Test Loss = 0.0676
# [Group A] Epoch 45/50: PGD Train Loss = 0.0176, Test Loss = 0.0770 | PGD-LM Train Loss = 0.0019, Test Loss = 0.0672
# [Group A] Epoch 46/50: PGD Train Loss = 0.0175, Test Loss = 0.0807 | PGD-LM Train Loss = 0.0018, Test Loss = 0.0679
# [Group A] Epoch 47/50: PGD Train Loss = 0.0168, Test Loss = 0.0830 | PGD-LM Train Loss = 0.0017, Test Loss = 0.0688
# [Group A] Epoch 48/50: PGD Train Loss = 0.0170, Test Loss = 0.0818 | PGD-LM Train Loss = 0.0016, Test Loss = 0.0676
# [Group A] Epoch 49/50: PGD Train Loss = 0.0166, Test Loss = 0.0864 | PGD-LM Train Loss = 0.0016, Test Loss = 0.0690
# [Group A] Epoch 50/50: PGD Train Loss = 0.0166, Test Loss = 0.0870 | PGD-LM Train Loss = 0.0015, Test Loss = 0.0684
# [Group B] Epoch 1/50:  NPGD Train Loss = 0.4077, Test Loss = 0.2331 |  NPGD-LM Train Loss = 0.4103, Test Loss = 0.2297
# [Group B] Epoch 2/50:  NPGD Train Loss = 0.1998, Test Loss = 0.1592 |  NPGD-LM Train Loss = 0.2028, Test Loss = 0.1636
# [Group B] Epoch 3/50:  NPGD Train Loss = 0.1540, Test Loss = 0.1152 |  NPGD-LM Train Loss = 0.1552, Test Loss = 0.1162
# [Group B] Epoch 4/50:  NPGD Train Loss = 0.1303, Test Loss = 0.2467 |  NPGD-LM Train Loss = 0.1313, Test Loss = 0.1827
# [Group B] Epoch 5/50:  NPGD Train Loss = 0.1152, Test Loss = 0.1114 |  NPGD-LM Train Loss = 0.1157, Test Loss = 0.1123
# [Group B] Epoch 6/50:  NPGD Train Loss = 0.1051, Test Loss = 0.0871 |  NPGD-LM Train Loss = 0.1066, Test Loss = 0.0866
# [Group B] Epoch 7/50:  NPGD Train Loss = 0.0965, Test Loss = 0.0852 |  NPGD-LM Train Loss = 0.0976, Test Loss = 0.0851
# [Group B] Epoch 8/50:  NPGD Train Loss = 0.0897, Test Loss = 0.0888 |  NPGD-LM Train Loss = 0.0904, Test Loss = 0.0912
# [Group B] Epoch 9/50:  NPGD Train Loss = 0.0854, Test Loss = 0.0947 |  NPGD-LM Train Loss = 0.0855, Test Loss = 0.0951
# [Group B] Epoch 10/50:  NPGD Train Loss = 0.0796, Test Loss = 0.0789 |  NPGD-LM Train Loss = 0.0802, Test Loss = 0.0775
# [Group B] Epoch 11/50:  NPGD Train Loss = 0.0759, Test Loss = 0.0760 |  NPGD-LM Train Loss = 0.0757, Test Loss = 0.0746
# [Group B] Epoch 12/50:  NPGD Train Loss = 0.0733, Test Loss = 0.0699 |  NPGD-LM Train Loss = 0.0730, Test Loss = 0.0699
# [Group B] Epoch 13/50:  NPGD Train Loss = 0.0699, Test Loss = 0.0746 |  NPGD-LM Train Loss = 0.0701, Test Loss = 0.0766
# [Group B] Epoch 14/50:  NPGD Train Loss = 0.0675, Test Loss = 0.0759 |  NPGD-LM Train Loss = 0.0672, Test Loss = 0.0751
# [Group B] Epoch 15/50:  NPGD Train Loss = 0.0655, Test Loss = 0.0712 |  NPGD-LM Train Loss = 0.0651, Test Loss = 0.0716
# [Group B] Epoch 16/50:  NPGD Train Loss = 0.0622, Test Loss = 0.0728 |  NPGD-LM Train Loss = 0.0628, Test Loss = 0.0745
# [Group B] Epoch 17/50:  NPGD Train Loss = 0.0605, Test Loss = 0.0753 |  NPGD-LM Train Loss = 0.0610, Test Loss = 0.0756
# [Group B] Epoch 18/50:  NPGD Train Loss = 0.0571, Test Loss = 0.0733 |  NPGD-LM Train Loss = 0.0585, Test Loss = 0.0740
# [Group B] Epoch 19/50:  NPGD Train Loss = 0.0553, Test Loss = 0.0678 |  NPGD-LM Train Loss = 0.0558, Test Loss = 0.0689
# [Group B] Epoch 20/50:  NPGD Train Loss = 0.0537, Test Loss = 0.0744 |  NPGD-LM Train Loss = 0.0545, Test Loss = 0.0800
# [Group B] Epoch 21/50:  NPGD Train Loss = 0.0531, Test Loss = 0.0768 |  NPGD-LM Train Loss = 0.0531, Test Loss = 0.0742
# [Group B] Epoch 22/50:  NPGD Train Loss = 0.0514, Test Loss = 0.0756 |  NPGD-LM Train Loss = 0.0519, Test Loss = 0.0733
# [Group B] Epoch 23/50:  NPGD Train Loss = 0.0501, Test Loss = 0.0725 |  NPGD-LM Train Loss = 0.0492, Test Loss = 0.0825
# [Group B] Epoch 24/50:  NPGD Train Loss = 0.0484, Test Loss = 0.0735 |  NPGD-LM Train Loss = 0.0483, Test Loss = 0.0720
# [Group B] Epoch 25/50:  NPGD Train Loss = 0.0472, Test Loss = 0.0718 |  NPGD-LM Train Loss = 0.0467, Test Loss = 0.0743
# [Group B] Epoch 26/50:  NPGD Train Loss = 0.0469, Test Loss = 0.0738 |  NPGD-LM Train Loss = 0.0463, Test Loss = 0.0732
# [Group B] Epoch 27/50:  NPGD Train Loss = 0.0452, Test Loss = 0.0699 |  NPGD-LM Train Loss = 0.0454, Test Loss = 0.0733
# [Group B] Epoch 28/50:  NPGD Train Loss = 0.0440, Test Loss = 0.0709 |  NPGD-LM Train Loss = 0.0436, Test Loss = 0.0725
# [Group B] Epoch 29/50:  NPGD Train Loss = 0.0435, Test Loss = 0.0727 |  NPGD-LM Train Loss = 0.0434, Test Loss = 0.0809
# [Group B] Epoch 30/50:  NPGD Train Loss = 0.0425, Test Loss = 0.0719 |  NPGD-LM Train Loss = 0.0428, Test Loss = 0.0785
# [Group B] Epoch 31/50:  NPGD Train Loss = 0.0410, Test Loss = 0.0718 |  NPGD-LM Train Loss = 0.0413, Test Loss = 0.0793
# [Group B] Epoch 32/50:  NPGD Train Loss = 0.0408, Test Loss = 0.0736 |  NPGD-LM Train Loss = 0.0408, Test Loss = 0.0799
# [Group B] Epoch 33/50:  NPGD Train Loss = 0.0393, Test Loss = 0.0714 |  NPGD-LM Train Loss = 0.0390, Test Loss = 0.0774
# [Group B] Epoch 34/50:  NPGD Train Loss = 0.0390, Test Loss = 0.0729 |  NPGD-LM Train Loss = 0.0385, Test Loss = 0.0770
# [Group B] Epoch 35/50:  NPGD Train Loss = 0.0383, Test Loss = 0.0822 |  NPGD-LM Train Loss = 0.0377, Test Loss = 0.0834
# [Group B] Epoch 36/50:  NPGD Train Loss = 0.0372, Test Loss = 0.0830 |  NPGD-LM Train Loss = 0.0366, Test Loss = 0.0846
# [Group B] Epoch 37/50:  NPGD Train Loss = 0.0366, Test Loss = 0.0793 |  NPGD-LM Train Loss = 0.0360, Test Loss = 0.0806
# [Group B] Epoch 38/50:  NPGD Train Loss = 0.0361, Test Loss = 0.0800 |  NPGD-LM Train Loss = 0.0348, Test Loss = 0.0817
# [Group B] Epoch 39/50:  NPGD Train Loss = 0.0359, Test Loss = 0.0813 |  NPGD-LM Train Loss = 0.0349, Test Loss = 0.0826
# [Group B] Epoch 40/50:  NPGD Train Loss = 0.0351, Test Loss = 0.0789 |  NPGD-LM Train Loss = 0.0346, Test Loss = 0.0835
# [Group B] Epoch 41/50:  NPGD Train Loss = 0.0343, Test Loss = 0.0795 |  NPGD-LM Train Loss = 0.0336, Test Loss = 0.0838
# [Group B] Epoch 42/50:  NPGD Train Loss = 0.0337, Test Loss = 0.0823 |  NPGD-LM Train Loss = 0.0337, Test Loss = 0.0818
# [Group B] Epoch 43/50:  NPGD Train Loss = 0.0331, Test Loss = 0.0849 |  NPGD-LM Train Loss = 0.0329, Test Loss = 0.0876
# [Group B] Epoch 44/50:  NPGD Train Loss = 0.0325, Test Loss = 0.0850 |  NPGD-LM Train Loss = 0.0327, Test Loss = 0.0843
# [Group B] Epoch 45/50:  NPGD Train Loss = 0.0323, Test Loss = 0.0773 |  NPGD-LM Train Loss = 0.0319, Test Loss = 0.0805
# [Group B] Epoch 46/50:  NPGD Train Loss = 0.0305, Test Loss = 0.0825 |  NPGD-LM Train Loss = 0.0319, Test Loss = 0.0834
# [Group B] Epoch 47/50:  NPGD Train Loss = 0.0313, Test Loss = 0.0850 |  NPGD-LM Train Loss = 0.0308, Test Loss = 0.0841
# [Group B] Epoch 48/50:  NPGD Train Loss = 0.0302, Test Loss = 0.0825 |  NPGD-LM Train Loss = 0.0303, Test Loss = 0.0854
# [Group B] Epoch 49/50:  NPGD Train Loss = 0.0311, Test Loss = 0.0891 |  NPGD-LM Train Loss = 0.0294, Test Loss = 0.0868
# [Group B] Epoch 50/50:  NPGD Train Loss = 0.0294, Test Loss = 0.0848 |  NPGD-LM Train Loss = 0.0295, Test Loss = 0.0854
# [Group C] Epoch 1/50 SGD with 5 runs: Train Loss = 0.3951, Test Loss = 0.2033
# [Group C] Epoch 2/50 SGD with 5 runs: Train Loss = 0.1784, Test Loss = 0.1417
# [Group C] Epoch 3/50 SGD with 5 runs: Train Loss = 0.1303, Test Loss = 0.1117
# [Group C] Epoch 4/50 SGD with 5 runs: Train Loss = 0.1074, Test Loss = 0.0974
# [Group C] Epoch 5/50 SGD with 5 runs: Train Loss = 0.0904, Test Loss = 0.0943
# [Group C] Epoch 6/50 SGD with 5 runs: Train Loss = 0.0786, Test Loss = 0.1442
# [Group C] Epoch 7/50 SGD with 5 runs: Train Loss = 0.0696, Test Loss = 0.0811
# [Group C] Epoch 8/50 SGD with 5 runs: Train Loss = 0.0621, Test Loss = 0.0746
# [Group C] Epoch 9/50 SGD with 5 runs: Train Loss = 0.0556, Test Loss = 0.0839
# [Group C] Epoch 10/50 SGD with 5 runs: Train Loss = 0.0508, Test Loss = 0.0731
# [Group C] Epoch 11/50 SGD with 5 runs: Train Loss = 0.0456, Test Loss = 0.0784
# [Group C] Epoch 12/50 SGD with 5 runs: Train Loss = 0.0410, Test Loss = 0.0936
# [Group C] Epoch 13/50 SGD with 5 runs: Train Loss = 0.0387, Test Loss = 0.0603
# [Group C] Epoch 14/50 SGD with 5 runs: Train Loss = 0.0351, Test Loss = 0.0612
# [Group C] Epoch 15/50 SGD with 5 runs: Train Loss = 0.0310, Test Loss = 0.0652
# [Group C] Epoch 16/50 SGD with 5 runs: Train Loss = 0.0287, Test Loss = 0.1451
# [Group C] Epoch 17/50 SGD with 5 runs: Train Loss = 0.0263, Test Loss = 0.0616
# [Group C] Epoch 18/50 SGD with 5 runs: Train Loss = 0.0232, Test Loss = 0.0638
# [Group C] Epoch 19/50 SGD with 5 runs: Train Loss = 0.0217, Test Loss = 0.0607
# [Group C] Epoch 20/50 SGD with 5 runs: Train Loss = 0.0189, Test Loss = 0.0615
# [Group C] Epoch 21/50 SGD with 5 runs: Train Loss = 0.0181, Test Loss = 0.0585
# [Group C] Epoch 22/50 SGD with 5 runs: Train Loss = 0.0165, Test Loss = 0.0607
# [Group C] Epoch 23/50 SGD with 5 runs: Train Loss = 0.0144, Test Loss = 0.0915
# [Group C] Epoch 24/50 SGD with 5 runs: Train Loss = 0.0133, Test Loss = 0.0609
# [Group C] Epoch 25/50 SGD with 5 runs: Train Loss = 0.0125, Test Loss = 0.0577
# [Group C] Epoch 26/50 SGD with 5 runs: Train Loss = 0.0114, Test Loss = 0.0607
# [Group C] Epoch 27/50 SGD with 5 runs: Train Loss = 0.0096, Test Loss = 0.0629
# [Group C] Epoch 28/50 SGD with 5 runs: Train Loss = 0.0086, Test Loss = 0.0588
# [Group C] Epoch 29/50 SGD with 5 runs: Train Loss = 0.0079, Test Loss = 0.0663
# [Group C] Epoch 30/50 SGD with 5 runs: Train Loss = 0.0071, Test Loss = 0.0605
# [Group C] Epoch 31/50 SGD with 5 runs: Train Loss = 0.0065, Test Loss = 0.0615
# [Group C] Epoch 32/50 SGD with 5 runs: Train Loss = 0.0056, Test Loss = 0.0622
# [Group C] Epoch 33/50 SGD with 5 runs: Train Loss = 0.0052, Test Loss = 0.0635
# [Group C] Epoch 34/50 SGD with 5 runs: Train Loss = 0.0046, Test Loss = 0.0644
# [Group C] Epoch 35/50 SGD with 5 runs: Train Loss = 0.0043, Test Loss = 0.0631
# [Group C] Epoch 36/50 SGD with 5 runs: Train Loss = 0.0039, Test Loss = 0.0627
# [Group C] Epoch 37/50 SGD with 5 runs: Train Loss = 0.0037, Test Loss = 0.0614
# [Group C] Epoch 38/50 SGD with 5 runs: Train Loss = 0.0032, Test Loss = 0.0614
# [Group C] Epoch 39/50 SGD with 5 runs: Train Loss = 0.0028, Test Loss = 0.0629
# [Group C] Epoch 40/50 SGD with 5 runs: Train Loss = 0.0027, Test Loss = 0.0635
# [Group C] Epoch 41/50 SGD with 5 runs: Train Loss = 0.0024, Test Loss = 0.0622
# [Group C] Epoch 42/50 SGD with 5 runs: Train Loss = 0.0024, Test Loss = 0.0663
# [Group C] Epoch 43/50 SGD with 5 runs: Train Loss = 0.0022, Test Loss = 0.0638
# [Group C] Epoch 44/50 SGD with 5 runs: Train Loss = 0.0021, Test Loss = 0.0646
# [Group C] Epoch 45/50 SGD with 5 runs: Train Loss = 0.0020, Test Loss = 0.0639
# [Group C] Epoch 46/50 SGD with 5 runs: Train Loss = 0.0018, Test Loss = 0.0679
# [Group C] Epoch 47/50 SGD with 5 runs: Train Loss = 0.0018, Test Loss = 0.0646
# [Group C] Epoch 48/50 SGD with 5 runs: Train Loss = 0.0017, Test Loss = 0.0638
# [Group C] Epoch 49/50 SGD with 5 runs: Train Loss = 0.0016, Test Loss = 0.0639
# [Group C] Epoch 50/50 SGD with 5 runs: Train Loss = 0.0015, Test Loss = 0.0652
# [Group C] Epoch 1/50 Particle Based SGD-LM: Train Loss = 0.3960, Test Loss = 0.2593
# [Group C] Epoch 2/50 Particle Based SGD-LM: Train Loss = 0.1781, Test Loss = 0.1404
# [Group C] Epoch 3/50 Particle Based SGD-LM: Train Loss = 0.1323, Test Loss = 0.1539
# [Group C] Epoch 4/50 Particle Based SGD-LM: Train Loss = 0.1074, Test Loss = 0.0960
# [Group C] Epoch 5/50 Particle Based SGD-LM: Train Loss = 0.0902, Test Loss = 0.0872
# [Group C] Epoch 6/50 Particle Based SGD-LM: Train Loss = 0.0787, Test Loss = 0.1073
# [Group C] Epoch 7/50 Particle Based SGD-LM: Train Loss = 0.0705, Test Loss = 0.0737
# [Group C] Epoch 8/50 Particle Based SGD-LM: Train Loss = 0.0621, Test Loss = 0.0832
# [Group C] Epoch 9/50 Particle Based SGD-LM: Train Loss = 0.0564, Test Loss = 0.0712
# [Group C] Epoch 10/50 Particle Based SGD-LM: Train Loss = 0.0504, Test Loss = 0.0652
# [Group C] Epoch 11/50 Particle Based SGD-LM: Train Loss = 0.0452, Test Loss = 0.0648
# [Group C] Epoch 12/50 Particle Based SGD-LM: Train Loss = 0.0422, Test Loss = 0.0684
# [Group C] Epoch 13/50 Particle Based SGD-LM: Train Loss = 0.0378, Test Loss = 0.0658
# [Group C] Epoch 14/50 Particle Based SGD-LM: Train Loss = 0.0359, Test Loss = 0.0703
# [Group C] Epoch 15/50 Particle Based SGD-LM: Train Loss = 0.0318, Test Loss = 0.0680
# [Group C] Epoch 16/50 Particle Based SGD-LM: Train Loss = 0.0283, Test Loss = 0.0599
# [Group C] Epoch 17/50 Particle Based SGD-LM: Train Loss = 0.0263, Test Loss = 0.0621
# [Group C] Epoch 18/50 Particle Based SGD-LM: Train Loss = 0.0235, Test Loss = 0.0644
# [Group C] Epoch 19/50 Particle Based SGD-LM: Train Loss = 0.0219, Test Loss = 0.0661
# [Group C] Epoch 20/50 Particle Based SGD-LM: Train Loss = 0.0203, Test Loss = 0.0629
# [Group C] Epoch 21/50 Particle Based SGD-LM: Train Loss = 0.0173, Test Loss = 0.0655
# [Group C] Epoch 22/50 Particle Based SGD-LM: Train Loss = 0.0163, Test Loss = 0.0652
# [Group C] Epoch 23/50 Particle Based SGD-LM: Train Loss = 0.0150, Test Loss = 0.0629
# [Group C] Epoch 24/50 Particle Based SGD-LM: Train Loss = 0.0134, Test Loss = 0.0649
# [Group C] Epoch 25/50 Particle Based SGD-LM: Train Loss = 0.0121, Test Loss = 0.0619
# [Group C] Epoch 26/50 Particle Based SGD-LM: Train Loss = 0.0111, Test Loss = 0.0648
# [Group C] Epoch 27/50 Particle Based SGD-LM: Train Loss = 0.0099, Test Loss = 0.0646
# [Group C] Epoch 28/50 Particle Based SGD-LM: Train Loss = 0.0089, Test Loss = 0.0648
# [Group C] Epoch 29/50 Particle Based SGD-LM: Train Loss = 0.0078, Test Loss = 0.0658
# [Group C] Epoch 30/50 Particle Based SGD-LM: Train Loss = 0.0067, Test Loss = 0.0653
# [Group C] Epoch 31/50 Particle Based SGD-LM: Train Loss = 0.0065, Test Loss = 0.0653
# [Group C] Epoch 32/50 Particle Based SGD-LM: Train Loss = 0.0057, Test Loss = 0.0647
# [Group C] Epoch 33/50 Particle Based SGD-LM: Train Loss = 0.0056, Test Loss = 0.0642
# [Group C] Epoch 34/50 Particle Based SGD-LM: Train Loss = 0.0048, Test Loss = 0.0661
# [Group C] Epoch 35/50 Particle Based SGD-LM: Train Loss = 0.0044, Test Loss = 0.0649
# [Group C] Epoch 36/50 Particle Based SGD-LM: Train Loss = 0.0039, Test Loss = 0.0669
# [Group C] Epoch 37/50 Particle Based SGD-LM: Train Loss = 0.0033, Test Loss = 0.0650
# [Group C] Epoch 38/50 Particle Based SGD-LM: Train Loss = 0.0030, Test Loss = 0.0661
# [Group C] Epoch 39/50 Particle Based SGD-LM: Train Loss = 0.0030, Test Loss = 0.0674
# [Group C] Epoch 40/50 Particle Based SGD-LM: Train Loss = 0.0026, Test Loss = 0.0676
# [Group C] Epoch 41/50 Particle Based SGD-LM: Train Loss = 0.0026, Test Loss = 0.0673
# [Group C] Epoch 42/50 Particle Based SGD-LM: Train Loss = 0.0024, Test Loss = 0.0673
# [Group C] Epoch 43/50 Particle Based SGD-LM: Train Loss = 0.0021, Test Loss = 0.0686
# [Group C] Epoch 44/50 Particle Based SGD-LM: Train Loss = 0.0020, Test Loss = 0.0684
# [Group C] Epoch 45/50 Particle Based SGD-LM: Train Loss = 0.0018, Test Loss = 0.0678
# [Group C] Epoch 46/50 Particle Based SGD-LM: Train Loss = 0.0018, Test Loss = 0.0689
# [Group C] Epoch 47/50 Particle Based SGD-LM: Train Loss = 0.0018, Test Loss = 0.0684
# [Group C] Epoch 48/50 Particle Based SGD-LM: Train Loss = 0.0017, Test Loss = 0.0687
# [Group C] Epoch 49/50 Particle Based SGD-LM: Train Loss = 0.0015, Test Loss = 0.0696
# [Group C] Epoch 50/50 Particle Based SGD-LM: Train Loss = 0.0016, Test Loss = 0.0700
# [Group D] Epoch 1/50 Adagrad with 5 runs: Train Loss = 1.0985, Test Loss = 0.1820
# [Group D] Epoch 2/50 Adagrad with 5 runs: Train Loss = 0.2156, Test Loss = 0.1493
# [Group D] Epoch 3/50 Adagrad with 5 runs: Train Loss = 0.1761, Test Loss = 0.1381
# [Group D] Epoch 4/50 Adagrad with 5 runs: Train Loss = 0.1519, Test Loss = 0.1215
# [Group D] Epoch 5/50 Adagrad with 5 runs: Train Loss = 0.1369, Test Loss = 0.1065
# [Group D] Epoch 6/50 Adagrad with 5 runs: Train Loss = 0.1251, Test Loss = 0.1041
# [Group D] Epoch 7/50 Adagrad with 5 runs: Train Loss = 0.1155, Test Loss = 0.1011
# [Group D] Epoch 8/50 Adagrad with 5 runs: Train Loss = 0.1085, Test Loss = 0.0962
# [Group D] Epoch 9/50 Adagrad with 5 runs: Train Loss = 0.1021, Test Loss = 0.0949
# [Group D] Epoch 10/50 Adagrad with 5 runs: Train Loss = 0.0962, Test Loss = 0.0889
# [Group D] Epoch 11/50 Adagrad with 5 runs: Train Loss = 0.0913, Test Loss = 0.0917
# [Group D] Epoch 12/50 Adagrad with 5 runs: Train Loss = 0.0875, Test Loss = 0.0839
# [Group D] Epoch 13/50 Adagrad with 5 runs: Train Loss = 0.0835, Test Loss = 0.0841
# [Group D] Epoch 14/50 Adagrad with 5 runs: Train Loss = 0.0803, Test Loss = 0.0826
# [Group D] Epoch 15/50 Adagrad with 5 runs: Train Loss = 0.0766, Test Loss = 0.0799
# [Group D] Epoch 16/50 Adagrad with 5 runs: Train Loss = 0.0735, Test Loss = 0.0827
# [Group D] Epoch 17/50 Adagrad with 5 runs: Train Loss = 0.0709, Test Loss = 0.0780
# [Group D] Epoch 18/50 Adagrad with 5 runs: Train Loss = 0.0681, Test Loss = 0.0815
# [Group D] Epoch 19/50 Adagrad with 5 runs: Train Loss = 0.0659, Test Loss = 0.0757
# [Group D] Epoch 20/50 Adagrad with 5 runs: Train Loss = 0.0639, Test Loss = 0.0748
# [Group D] Epoch 21/50 Adagrad with 5 runs: Train Loss = 0.0617, Test Loss = 0.0816
# [Group D] Epoch 22/50 Adagrad with 5 runs: Train Loss = 0.0598, Test Loss = 0.0756
# [Group D] Epoch 23/50 Adagrad with 5 runs: Train Loss = 0.0579, Test Loss = 0.0752
# [Group D] Epoch 24/50 Adagrad with 5 runs: Train Loss = 0.0564, Test Loss = 0.0756
# [Group D] Epoch 25/50 Adagrad with 5 runs: Train Loss = 0.0545, Test Loss = 0.0754
# [Group D] Epoch 26/50 Adagrad with 5 runs: Train Loss = 0.0528, Test Loss = 0.0734
# [Group D] Epoch 27/50 Adagrad with 5 runs: Train Loss = 0.0513, Test Loss = 0.0717
# [Group D] Epoch 28/50 Adagrad with 5 runs: Train Loss = 0.0499, Test Loss = 0.0728
# [Group D] Epoch 29/50 Adagrad with 5 runs: Train Loss = 0.0484, Test Loss = 0.0728
# [Group D] Epoch 30/50 Adagrad with 5 runs: Train Loss = 0.0472, Test Loss = 0.0729
# [Group D] Epoch 31/50 Adagrad with 5 runs: Train Loss = 0.0462, Test Loss = 0.0720
# [Group D] Epoch 32/50 Adagrad with 5 runs: Train Loss = 0.0452, Test Loss = 0.0717
# [Group D] Epoch 33/50 Adagrad with 5 runs: Train Loss = 0.0438, Test Loss = 0.0704
# [Group D] Epoch 34/50 Adagrad with 5 runs: Train Loss = 0.0426, Test Loss = 0.0725
# [Group D] Epoch 35/50 Adagrad with 5 runs: Train Loss = 0.0417, Test Loss = 0.0692
# [Group D] Epoch 36/50 Adagrad with 5 runs: Train Loss = 0.0406, Test Loss = 0.0685
# [Group D] Epoch 37/50 Adagrad with 5 runs: Train Loss = 0.0397, Test Loss = 0.0719
# [Group D] Epoch 38/50 Adagrad with 5 runs: Train Loss = 0.0388, Test Loss = 0.0713
# [Group D] Epoch 39/50 Adagrad with 5 runs: Train Loss = 0.0378, Test Loss = 0.0710
# [Group D] Epoch 40/50 Adagrad with 5 runs: Train Loss = 0.0369, Test Loss = 0.0743
# [Group D] Epoch 41/50 Adagrad with 5 runs: Train Loss = 0.0361, Test Loss = 0.0706
# [Group D] Epoch 42/50 Adagrad with 5 runs: Train Loss = 0.0351, Test Loss = 0.0708
# [Group D] Epoch 43/50 Adagrad with 5 runs: Train Loss = 0.0344, Test Loss = 0.0694
# [Group D] Epoch 44/50 Adagrad with 5 runs: Train Loss = 0.0338, Test Loss = 0.0697
# [Group D] Epoch 45/50 Adagrad with 5 runs: Train Loss = 0.0328, Test Loss = 0.0702
# [Group D] Epoch 46/50 Adagrad with 5 runs: Train Loss = 0.0324, Test Loss = 0.0699
# [Group D] Epoch 47/50 Adagrad with 5 runs: Train Loss = 0.0316, Test Loss = 0.0715
# [Group D] Epoch 48/50 Adagrad with 5 runs: Train Loss = 0.0309, Test Loss = 0.0716
# [Group D] Epoch 49/50 Adagrad with 5 runs: Train Loss = 0.0301, Test Loss = 0.0705
# [Group D] Epoch 50/50 Adagrad with 5 runs: Train Loss = 0.0294, Test Loss = 0.0694
# [Group D] Epoch 1/50 Particle Based Adagrad-LM: Train Loss = 4.0477, Test Loss = 1.9365
# [Group D] Epoch 2/50 Particle Based Adagrad-LM: Train Loss = 2.1265, Test Loss = 1.7980
# [Group D] Epoch 3/50 Particle Based Adagrad-LM: Train Loss = 2.0860, Test Loss = 1.7798
# [Group D] Epoch 4/50 Particle Based Adagrad-LM: Train Loss = 2.0715, Test Loss = 1.7352
# [Group D] Epoch 5/50 Particle Based Adagrad-LM: Train Loss = 2.0345, Test Loss = 1.5988
# [Group D] Epoch 6/50 Particle Based Adagrad-LM: Train Loss = 1.9887, Test Loss = 1.5680
# [Group D] Epoch 7/50 Particle Based Adagrad-LM: Train Loss = 1.9466, Test Loss = 1.5141
# [Group D] Epoch 8/50 Particle Based Adagrad-LM: Train Loss = 1.9067, Test Loss = 1.4525
# [Group D] Epoch 9/50 Particle Based Adagrad-LM: Train Loss = 1.8627, Test Loss = 1.4755
# [Group D] Epoch 10/50 Particle Based Adagrad-LM: Train Loss = 1.8194, Test Loss = 1.4593
# [Group D] Epoch 11/50 Particle Based Adagrad-LM: Train Loss = 1.8008, Test Loss = 1.4442
# [Group D] Epoch 12/50 Particle Based Adagrad-LM: Train Loss = 1.7928, Test Loss = 1.4873
# [Group D] Epoch 13/50 Particle Based Adagrad-LM: Train Loss = 1.7862, Test Loss = 1.4430
# [Group D] Epoch 14/50 Particle Based Adagrad-LM: Train Loss = 1.7786, Test Loss = 1.4609
# [Group D] Epoch 15/50 Particle Based Adagrad-LM: Train Loss = 1.7696, Test Loss = 1.4032
# [Group D] Epoch 16/50 Particle Based Adagrad-LM: Train Loss = 1.7625, Test Loss = 1.4003
# [Group D] Epoch 17/50 Particle Based Adagrad-LM: Train Loss = 1.7576, Test Loss = 1.4671
# [Group D] Epoch 18/50 Particle Based Adagrad-LM: Train Loss = 1.7530, Test Loss = 1.5010
# [Group D] Epoch 19/50 Particle Based Adagrad-LM: Train Loss = 1.7434, Test Loss = 1.5483
# [Group D] Epoch 20/50 Particle Based Adagrad-LM: Train Loss = 1.7355, Test Loss = 1.5198
# [Group D] Epoch 21/50 Particle Based Adagrad-LM: Train Loss = 1.7383, Test Loss = 1.4856
# [Group D] Epoch 22/50 Particle Based Adagrad-LM: Train Loss = 1.7297, Test Loss = 1.5234
# [Group D] Epoch 23/50 Particle Based Adagrad-LM: Train Loss = 1.7268, Test Loss = 1.5207
# [Group D] Epoch 24/50 Particle Based Adagrad-LM: Train Loss = 1.7238, Test Loss = 1.4655
# [Group D] Epoch 25/50 Particle Based Adagrad-LM: Train Loss = 1.7220, Test Loss = 1.4275
# [Group D] Epoch 26/50 Particle Based Adagrad-LM: Train Loss = 1.7207, Test Loss = 1.5109
# [Group D] Epoch 27/50 Particle Based Adagrad-LM: Train Loss = 1.7204, Test Loss = 1.5003
# [Group D] Epoch 28/50 Particle Based Adagrad-LM: Train Loss = 1.7174, Test Loss = 1.4295
# [Group D] Epoch 29/50 Particle Based Adagrad-LM: Train Loss = 1.7131, Test Loss = 1.4326
# [Group D] Epoch 30/50 Particle Based Adagrad-LM: Train Loss = 1.7144, Test Loss = 1.4340
# [Group D] Epoch 31/50 Particle Based Adagrad-LM: Train Loss = 1.7122, Test Loss = 1.4839
# [Group D] Epoch 32/50 Particle Based Adagrad-LM: Train Loss = 1.7101, Test Loss = 1.4694
# [Group D] Epoch 33/50 Particle Based Adagrad-LM: Train Loss = 1.7078, Test Loss = 1.4403
# [Group D] Epoch 34/50 Particle Based Adagrad-LM: Train Loss = 1.7068, Test Loss = 1.4156
# [Group D] Epoch 35/50 Particle Based Adagrad-LM: Train Loss = 1.7083, Test Loss = 1.5046
# [Group D] Epoch 36/50 Particle Based Adagrad-LM: Train Loss = 1.7057, Test Loss = 1.4089
# [Group D] Epoch 37/50 Particle Based Adagrad-LM: Train Loss = 1.7046, Test Loss = 1.4359
# [Group D] Epoch 38/50 Particle Based Adagrad-LM: Train Loss = 1.7016, Test Loss = 1.4269
# [Group D] Epoch 39/50 Particle Based Adagrad-LM: Train Loss = 1.7021, Test Loss = 1.4241
# [Group D] Epoch 40/50 Particle Based Adagrad-LM: Train Loss = 1.7034, Test Loss = 1.4495
# [Group D] Epoch 41/50 Particle Based Adagrad-LM: Train Loss = 1.7013, Test Loss = 1.4421
# [Group D] Epoch 42/50 Particle Based Adagrad-LM: Train Loss = 1.6991, Test Loss = 1.4348
# [Group D] Epoch 43/50 Particle Based Adagrad-LM: Train Loss = 1.6987, Test Loss = 1.4382
# [Group D] Epoch 44/50 Particle Based Adagrad-LM: Train Loss = 1.6982, Test Loss = 1.4698
# [Group D] Epoch 45/50 Particle Based Adagrad-LM: Train Loss = 1.6985, Test Loss = 1.4762
# [Group D] Epoch 46/50 Particle Based Adagrad-LM: Train Loss = 1.6974, Test Loss = 1.4215
# [Group D] Epoch 47/50 Particle Based Adagrad-LM: Train Loss = 1.6956, Test Loss = 1.4243
# [Group D] Epoch 48/50 Particle Based Adagrad-LM: Train Loss = 1.6956, Test Loss = 1.4099
# [Group D] Epoch 49/50 Particle Based Adagrad-LM: Train Loss = 1.6967, Test Loss = 1.4006
# [Group D] Epoch 50/50 Particle Based Adagrad-LM: Train Loss = 1.6954, Test Loss = 1.4374

# %% [markdown]
# ## Visualization and Result Analysis

# %%
# Group A
figA, (axA1, axA2) = plt.subplots(1, 2, figsize=(14,6))
axA1.plot(train_loss_A['PGD'], label="PGD Train", marker='o')
axA1.plot(train_loss_A['PGD-LM'], label="PGD-LM Train", marker='o')
axA1.set_xlabel("Epoch")
axA1.set_ylabel("Training Loss")
axA1.set_title("Group A: Training Loss")
axA1.legend(); axA1.grid(True)
axA2.plot(test_loss_A['PGD'], label="PGD Test", marker='o')
axA2.plot(test_loss_A['PGD-LM'], label="PGD-LM Test", marker='o')
axA2.set_xlabel("Epoch")
axA2.set_ylabel("Test Loss")
axA2.set_title("Group A: Test Loss")
axA2.legend(); axA2.grid(True)
plt.show()

# Group B
figB, (axB1, axB2) = plt.subplots(1, 2, figsize=(14,6))
axB1.plot(train_loss_B['NPGD'], label="NPGD Train", marker='o')
axB1.plot(train_loss_B['NPGD-LM'], label="NPGD-LM Train", marker='o')
axB1.set_xlabel("Epoch")
axB1.set_ylabel("Training Loss")
axB1.set_title("Group B: Training Loss")
axB1.legend(); axB1.grid(True)
axB2.plot(test_loss_B['NPGD'], label="NPGD Test", marker='o')
axB2.plot(test_loss_B['NPGD-LM'], label="NPGD-LM Test", marker='o')
axB2.set_xlabel("Epoch")
axB2.set_ylabel("Test Loss")
axB2.set_title("Group B: Test Loss")
axB2.legend(); axB2.grid(True)
plt.show()

# Group C
figC, (axC1, axC2) = plt.subplots(1, 2, figsize=(14,6))
axC1.plot(loss_B_ind_train, label="SGD with 5 runs Train", marker='o')
axC1.plot(loss_B_lm_train, label="Particle Based SGD-LM Train", marker='o')
axC1.set_xlabel("Epoch")
axC1.set_ylabel("Training Loss")
axC1.set_title("Group C: Training Loss")
axC1.legend(); axC1.grid(True)
axC2.plot(loss_B_ind_test, label="SGD with 5 runs Test", marker='o')
axC2.plot(loss_B_lm_test, label="Particle Based SGD-LM Test", marker='o')
axC2.set_xlabel("Epoch")
axC2.set_ylabel("Test Loss")
axC2.set_title("Group C: Test Loss")
axC2.legend(); axC2.grid(True)
plt.show()

# Group D
figD, (axD1, axD2) = plt.subplots(1, 2, figsize=(14,6))
axD1.plot(loss_C_ind_train, label="Adagrad with 5 runs Train", marker='o')
axD1.plot(loss_C_lm_train, label="Particle Based Adagrad-LM Train", marker='o')
axD1.set_xlabel("Epoch")
axD1.set_ylabel("Training Loss")
axD1.set_title("Group D: Training Loss")
axD1.legend(); axD1.grid(True)
axD2.plot(loss_C_ind_test, label="Adagrad with 5 runs Test", marker='o')
axD2.plot(loss_C_lm_test, label="Particle Based Adagrad-LM Test", marker='o')
axD2.set_xlabel("Epoch")
axD2.set_ylabel("Test Loss")
axD2.set_title("Group D: Test Loss")
axD2.legend(); axD2.grid(True)
plt.show()

# Results
avg_train_loss_A = {
    'PGD': np.mean(train_loss_A['PGD']),
    'PGD-LM': np.mean(train_loss_A['PGD-LM'])
}
avg_test_loss_A = {
    'PGD': np.mean(test_loss_A['PGD']),
    'PGD-LM': np.mean(test_loss_A['PGD-LM'])
}
avg_train_loss_B_ind = np.mean(train_loss_B['NPGD'])
avg_test_loss_B_ind  = np.mean(test_loss_B['NPGD'])
avg_train_loss_B_lm  = np.mean(train_loss_B['NPGD-LM'])
avg_test_loss_B_lm   = np.mean(test_loss_B['NPGD-LM'])
avg_train_loss_C_ind = np.mean(loss_B_ind_train)
avg_test_loss_C_ind  = np.mean(loss_B_ind_test)
avg_train_loss_C_lm  = np.mean(loss_B_lm_train)
avg_test_loss_C_lm   = np.mean(loss_B_lm_test)
avg_train_loss_D_ind = np.mean(loss_C_ind_train)
avg_test_loss_D_ind  = np.mean(loss_C_ind_test)
avg_train_loss_D_lm  = np.mean(loss_C_lm_train)
avg_test_loss_D_lm   = np.mean(loss_C_lm_test)

print("\nAverage Losses:")
print(f"Group A (PGD) - Train = {avg_train_loss_A['PGD']:.4f}, Test = {avg_test_loss_A['PGD']:.4f}")
print(f"Group A (PGD-LM) - Train = {avg_train_loss_A['PGD-LM']:.4f}, Test = {avg_test_loss_A['PGD-LM']:.4f}")
print(f"Group B (NPGD) - Train = {avg_train_loss_B_ind:.4f}, Test = {avg_test_loss_B_ind:.4f}")
print(f"Group B (NPGD-LM) - Train = {avg_train_loss_B_lm:.4f}, Test = {avg_test_loss_B_lm:.4f}")
print(f"Group C (SGD with 5 runs) - Train = {avg_train_loss_C_ind:.4f}, Test = {avg_test_loss_C_ind:.4f}")
print(f"Group C (Particle Based SGD-LM) - Train = {avg_train_loss_C_lm:.4f}, Test = {avg_test_loss_C_lm:.4f}")
print(f"Group D (Adagrad with 5 runs) - Train = {avg_train_loss_D_ind:.4f}, Test = {avg_test_loss_D_ind:.4f}")
print(f"Group D (Particle Based Adagrad-LM) - Train = {avg_train_loss_D_lm:.4f}, Test = {avg_test_loss_D_lm:.4f}")

def eval_ensemble(models, loader):
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            outputs_sum = 0
            for m in models:
                outputs_sum += m(images)
            outputs_avg = outputs_sum / len(models)
            _, predicted = torch.max(outputs_avg, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return 100 * correct / total

acc_A_PGD    = evaluate(models_A_PGD, test_loader)
acc_A_PGD_LM = evaluate(models_A_PGD_LM, test_loader)
acc_B_NPGD    = evaluate(models_B_NPGD, test_loader)
acc_B_NPGD_LM = evaluate(models_B_NPGD_LM, test_loader)
acc_C_SGD     = evaluate(models_C_ind, test_loader)
acc_C_SGD_LM  = evaluate(models_C_lm, test_loader)
acc_D_Adagrad     = evaluate(models_D_ind, test_loader)
acc_D_Adagrad_LM  = evaluate(models_D_lm, test_loader)

print("\nFinal Test Accuracy:")
print(f"Group A (PGD): {acc_A_PGD:.2f}%, PGD-LM: {acc_A_PGD_LM:.2f}%")
print(f"Group B (NPGD): {acc_B_NPGD:.2f}%, NPGD-LM : {acc_B_NPGD_LM:.2f}%")
print(f"Group C (SGD with 5 runs): {acc_C_SGD:.2f}%, Particle Based SGD-LM: {acc_C_SGD_LM:.2f}%")
print(f"Group D (Adagrad with 5 runs): {acc_D_Adagrad:.2f}%, Particle Based Adagrad-LM: {acc_D_Adagrad_LM:.2f}%")
# Out:
# Average Losses:
# Group A (PGD) - Train = 0.0505, Test = 0.0845
# Group A (PGD-LM) - Train = 0.0341, Test = 0.0780
# Group B (NPGD) - Train = 0.0655, Test = 0.0874
# Group B (NPGD-LM) - Train = 0.0656, Test = 0.0878
# Group C (SGD with 5 runs) - Train = 0.0342, Test = 0.0754
# Group C (Particle Based SGD-LM) - Train = 0.0343, Test = 0.0756
# Group D (Adagrad with 5 runs) - Train = 0.0874, Test = 0.0832
# Group D (Particle Based Adagrad-LM) - Train = 1.8167, Test = 1.4907
#
# Final Test Accuracy:
# Group A (PGD): 98.32%, PGD-LM: 98.30%
# Group B (NPGD): 98.27%, NPGD-LM : 98.19%
# Group C (SGD with 5 runs): 98.27%, Particle Based SGD-LM: 98.25%
# Group D (Adagrad with 5 runs): 98.01%, Particle Based Adagrad-LM: 51.27%
